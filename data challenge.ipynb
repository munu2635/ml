# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dataset_kor = pd.read_csv('Train-data.csv', encoding='euc-kr')
dataset_kor.head(5)
# Out:
#     발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수    ...      \
# 0  2017  2017063023   14  야간  금     1     1     0     0       0    ...
# 1  2017  2017063021   45  야간  금     1     4     2     1       0    ...
# 2  2017  2017063021   50  야간  금     1     1     0     0       0    ...
# 3  2017  2017063019   10  야간  금     1     1     0     0       0    ...
# 4  2017  2017063017    2  주간  금     1     2     1     0       0    ...
#
#   도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# 0      단일로  기타단일로          승용차      승용차          보행자      보행자     967633
# 1      단일로  기타단일로          승용차      승용차          승용차      승용차     966456
# 2      단일로  기타단일로          승용차      승용차          보행자      보행자     900057
# 3      교차로  교차로부근          승용차      승용차          이륜차      이륜차    1095230
# 4      단일로    교량위          이륜차      이륜차          화물차      화물차     947576
#
#   발생위치Y_UTMK          경도         위도
# 0    1937456  127.134130  37.435704
# ...

# %%
dataset_kor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25037 entries, 0 to 25036
# Data columns (total 27 columns):
# 발생년             25037 non-null int64
# 발생년월일시          25037 non-null int64
# 발생분             25037 non-null int64
# 주야              25037 non-null object
# 요일              25037 non-null object
# 사망자수            25037 non-null int64
# 사상자수            25037 non-null int64
# 중상자수            25037 non-null int64
# 경상자수            25037 non-null int64
# 부상신고자수          25037 non-null int64
# 발생지시도           25037 non-null object
# 발생지시군구          25037 non-null object
# 사고유형_대분류        25037 non-null object
# 사고유형_중분류        25037 non-null object
# 사고유형            25037 non-null object
# 법규위반_대분류        25037 non-null object
# 법규위반            25037 non-null object
# 도로형태_대분류        25037 non-null object
# 도로형태            25037 non-null object
# 당사자종별_1당_대분류    25037 non-null object
# 당사자종별_1당        25037 non-null object
# 당사자종별_2당_대분류    24212 non-null object
# ...

# %%
dataset_kor.describe()
# Out:
#                 발생년        발생년월일시           발생분          사망자수         사상자수  \
# count  25037.000000  2.503700e+04  25037.000000  25037.000000  25037.00000
# mean    2014.120621  2.014187e+09     27.155769      1.040899      1.62152
# std        1.582751  1.579004e+06     17.356025      0.252493      2.05103
# min     2012.000000  2.012010e+09      0.000000      1.000000      1.00000
# 25%     2013.000000  2.013040e+09     11.000000      1.000000      1.00000
# 50%     2014.000000  2.014073e+09     28.000000      1.000000      1.00000
# 75%     2015.000000  2.015121e+09     40.000000      1.000000      2.00000
# max     2017.000000  2.017063e+09     59.000000     10.000000    100.00000
#
#                중상자수          경상자수        부상신고자수    발생위치X_UTMK    발생위치Y_UTMK  \
# count  25037.000000  25037.000000  25037.000000  2.503700e+04  2.503700e+04
# mean       0.299996      0.250509      0.030115  1.007374e+06  1.817230e+06
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
dataset_kor.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
dataset_kor.plot(kind="scatter", x="경도", y="위도")

# %%
dataset_kor.plot(kind="scatter", x="경도", y="위도", alpha=0.4, 
             s=dataset_kor["발생분"]/100, label="발생분", figsize=(10, 7),
             c="사망자수", cmap=plt.get_cmap("jet"), colorbar=True, sharex=False)
plt.legend()
